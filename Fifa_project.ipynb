# %% [markdown]
# <a href="https://colab.research.google.com/github/MDAnsaar25/Fifa-players-and-team-analysis/blob/main/Fifa_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fifa = pd.read_csv('/content/drive/MyDrive/Data Sets/fifa_game_data (1).csv')

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Find the number of rows and columns in dataset ?
fifa.shape
# Out:
# (18207, 89)

# %%
# Print the name of all the columns(attributes) with the help of for loop ?
for col in fifa.columns:
  print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
fifa['Nationality'].value_counts() # Let's calculate the total number of player in the list by their nationality
# Out:
# Nationality
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
#                ...
# Malta             1
# Belize            1
# South Sudan       1
# Indonesia         1
# Botswana          1
# Name: count, Length: 164, dtype: int64

# %%
fifa['Nationality'].value_counts().head() # first five.
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
students_country = (fifa['Nationality']=='India').value_counts()
print(students_country) # This finds the number of player which are from that country. The true gives the numbers so here it is 23.
# Out:
# Nationality
# False    18177
# True        30
# Name: count, dtype: int64

# %%
fifa[fifa['Nationality']=='India'].head()
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 8605         8605  190939       S. Chhetri   33
# 10011       10011  223763       S. Jhingan   24
# 12598       12598  217225    J. Lalpekhlua   27
# 12811       12811  225213  G. Singh Sandhu   26
# 13508       13508  238205    A. Edathodika   31
#
#                                                 Photo Nationality  \
# 8605   https://cdn.sofifa.org/players/4/19/190939.png       India
# 10011  https://cdn.sofifa.org/players/4/19/223763.png       India
# 12598  https://cdn.sofifa.org/players/4/19/217225.png       India
# 12811  https://cdn.sofifa.org/players/4/19/225213.png       India
# 13508  https://cdn.sofifa.org/players/4/19/238205.png       India
#
#                                        Flag  Overall  Potential Club  ...  \
# 8605   https://cdn.sofifa.org/flags/159.png       67         67  NaN  ...
# 10011  https://cdn.sofifa.org/flags/159.png       65         71  NaN  ...
# ...

# %%
fifa['Nationality'].value_counts()[0:10] # Calculating first 10 countries with highest number.
# Out:
# Nationality
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: count, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5].keys() # We are using keys to get the name of first 5 countries.
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France'], dtype='object', name='Nationality')

# %%
plt.figure(figsize=(8,5))
plt.bar(    list(fifa['Nationality'].value_counts()[0:5].keys()),list(fifa['Nationality'].value_counts()[0:5]),color="g")  # We converted the keys to list to use them for x-axis and the total number of games for y-axis.
# Please explain that it is important to convert the data to list.
# Out:
# <BarContainer object of 5 artists>

# %%
player_salary = fifa[['Name','Wage']] # Let's find the name and wage of player.
player_salary.head()
# Out:
#                 Name   Wage
# 0           L. Messi  €565K
# 1  Cristiano Ronaldo  €405K
# 2          Neymar Jr  €290K
# 3             De Gea  €260K
# 4       K. De Bruyne  €355K

# %%
player_salary=player_salary.sort_values(by=['Wage'],ascending=False) # First five. Here the ascending = False means that it will be in descending order. By default it is ascending.
player_salary.head()
# Out:
#               Name Wage
# 6615   C. Teuchert  €9K
# 4511      K. Narey  €9K
# 10633      J. Ngoy  €9K
# 2819      J. Mišić  €9K
# 2817   J. Gandolfi  €9K

# %%
print(player_salary.shape)
print(player_salary.head())
print(player_salary[['Name', 'Wage']].head())          #Convert them to numbers
# Out:
# (18207, 2)
#               Name Wage
# 6615   C. Teuchert  €9K
# 4511      K. Narey  €9K
# 10633      J. Ngoy  €9K
# 2819      J. Mišić  €9K
# 2817   J. Gandolfi  €9K
#               Name Wage
# 6615   C. Teuchert  €9K
# 4511      K. Narey  €9K
# 10633      J. Ngoy  €9K
# 2819      J. Mišić  €9K
# 2817   J. Gandolfi  €9K

# %%
x = list(player_salary['Name'])[:5]
y = list(player_salary['Wage'])[:5]

print("x:", x)
print("y:", y)
# Out:
# x: ['C. Teuchert', 'K. Narey', 'J. Ngoy', 'J. Mišić', 'J. Gandolfi']
# y: ['€9K', '€9K', '€9K', '€9K', '€9K']

# %%
print(player_salary['Wage'].dtype)
print(player_salary['Wage'].head())
# Out:
# float64
# 6615     9.0
# 4511     9.0
# 10633    9.0
# 2819     9.0
# 2817     9.0
# Name: Wage, dtype: float64

# %%
plt.figure(figsize=(8, 5))
plt.bar(player_salary['Name'][:5], player_salary['Wage'][:5], color='r')
plt.xticks(rotation=45)
plt.show()

# %%
Germany.sort_values(by=['Height'],ascending=False).head()  # Sort by height
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 1426         1426  199833  L. Unnerstall   27
# 13540       13540  208776    F. Stritzel   24
# 17786       17786  240218   A. Weidinger   21
# 13520       13520  239746   L. Watkowiak   22
# 4542         4542  158657     T. Kessler   32
#
#                                                 Photo Nationality  \
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 13540  https://cdn.sofifa.org/players/4/19/208776.png     Germany
# 17786  https://cdn.sofifa.org/players/4/19/240218.png     Germany
# 13520  https://cdn.sofifa.org/players/4/19/239746.png     Germany
# 4542   https://cdn.sofifa.org/players/4/19/158657.png     Germany
#
#                                       Flag  Overall  Potential  \
# 1426   https://cdn.sofifa.org/flags/21.png       76         78
# 13540  https://cdn.sofifa.org/flags/21.png       62         67
# 17786  https://cdn.sofifa.org/flags/21.png       52         60
# ...

# %%
Germany.sort_values(by=['Weight'],ascending=False).head() # sort by weight
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 13520       13520  239746   L. Watkowiak   22
# 1426         1426  199833  L. Unnerstall   27
# 210           210  179783    R. Fährmann   29
# 1225         1225  200212       M. Esser   30
# 115           115  212190        N. Süle   22
#
#                                                 Photo Nationality  \
# 13520  https://cdn.sofifa.org/players/4/19/239746.png     Germany
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 210    https://cdn.sofifa.org/players/4/19/179783.png     Germany
# 1225   https://cdn.sofifa.org/players/4/19/200212.png     Germany
# 115    https://cdn.sofifa.org/players/4/19/212190.png     Germany
#
#                                       Flag  Overall  Potential  \
# 13520  https://cdn.sofifa.org/flags/21.png       62         68
# 1426   https://cdn.sofifa.org/flags/21.png       76         78
# 210    https://cdn.sofifa.org/flags/21.png       83         84
# ...

# %%
Germany.sort_values(by=['Wage'],ascending=False).head() # sort by wage
# Out:
#       Unnamed: 0      ID         Name  Age  \
# 3147        3147  204776  T. Leistner   27
# 5259        5259  235407     S. Özcan   20
# 6615        6615  226050  C. Teuchert   21
# 6376        6376  231110     P. Erras   23
# 6323        6323  190648    S. Sirigu   29
#
#                                                Photo Nationality  \
# 3147  https://cdn.sofifa.org/players/4/19/204776.png     Germany
# 5259  https://cdn.sofifa.org/players/4/19/235407.png     Germany
# 6615  https://cdn.sofifa.org/players/4/19/226050.png     Germany
# 6376  https://cdn.sofifa.org/players/4/19/231110.png     Germany
# 6323  https://cdn.sofifa.org/players/4/19/190648.png     Germany
#
#                                      Flag  Overall  Potential  \
# 3147  https://cdn.sofifa.org/flags/21.png       73         74
# 5259  https://cdn.sofifa.org/flags/21.png       70         85
# 6615  https://cdn.sofifa.org/flags/21.png       68         81
# ...

# %%
Germany[['Name','Wage']].sort_values(by=['Wage'],ascending=False).head() # show only name and wages and sort them in descending order.
# Out:
#              Name Wage
# 3147  T. Leistner  €9K
# 5259     S. Özcan  €9K
# 6615  C. Teuchert  €9K
# 6376     P. Erras  €9K
# 6323    S. Sirigu  €9K

# %%
player_shooting=fifa[['Name','Finishing']]

# %%
player_shooting.sort_values(by=['Finishing'],ascending=False).head()
# Out:
#                  Name  Finishing
# 0            L. Messi       95.0
# 1   Cristiano Ronaldo       94.0
# 16            H. Kane       94.0
# 7           L. Suárez       93.0
# 23          S. Agüero       93.0

# %%
player_defending=fifa[['Name','HeadingAccuracy','Nationality','Club']]

# %%
player_defending.sort_values(by=['HeadingAccuracy'],ascending=False).head()
# Out:
#              Name  HeadingAccuracy  Nationality               Club
# 102         Naldo             94.0       Brazil      FC Schalke 04
# 204       B. Dost             94.0  Netherlands        Sporting CP
# 818  L. Pavoletti             93.0        Italy           Cagliari
# 700   M. Fellaini             93.0      Belgium  Manchester United
# 499    L. de Jong             93.0  Netherlands                PSV

# %%
real_madrid= fifa[fifa['Club']=='Real Madrid']
real_madrid.sort_values(by=['Wage'],ascending=False).head() # Ask student to find out the top 5 people who earn maximum from their favourite footaball club. Here it is real madrid.
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 13687       13687  240311      L. Zidane   20
# 11877       11877  243155  Manu Hernando   19
# 11327       11327  246606    Fran García   18
# 11163       11163  245287   Sergio López   19
# 754           754  225161        Vallejo   21
#
#                                                 Photo Nationality  \
# 13687  https://cdn.sofifa.org/players/4/19/240311.png      France
# 11877  https://cdn.sofifa.org/players/4/19/243155.png       Spain
# 11327  https://cdn.sofifa.org/players/4/19/246606.png       Spain
# 11163  https://cdn.sofifa.org/players/4/19/245287.png       Spain
# 754    https://cdn.sofifa.org/players/4/19/225161.png       Spain
#
#                                       Flag  Overall  Potential         Club  \
# 13687  https://cdn.sofifa.org/flags/18.png       62         71  Real Madrid
# 11877  https://cdn.sofifa.org/flags/45.png       64         76  Real Madrid
# ...

# %%
real_madrid.sort_values(by=['Finishing'],ascending=False).head() # Sort in descending order on basis of Finishing capabilties in real madrid.
# Out:
#      Unnamed: 0      ID           Name  Age  \
# 36           36  173731        G. Bale   28
# 79           79  220834  Marco Asensio   22
# 105         105  165153     K. Benzema   30
# 430         430  221639        Mariano   24
# 30           30  197781           Isco   26
#
#                                               Photo         Nationality  \
# 36   https://cdn.sofifa.org/players/4/19/173731.png               Wales
# 79   https://cdn.sofifa.org/players/4/19/220834.png               Spain
# 105  https://cdn.sofifa.org/players/4/19/165153.png              France
# 430  https://cdn.sofifa.org/players/4/19/221639.png  Dominican Republic
# 30   https://cdn.sofifa.org/players/4/19/197781.png               Spain
#
#                                      Flag  Overall  Potential         Club  \
# 36    https://cdn.sofifa.org/flags/50.png       88         88  Real Madrid
# 79    https://cdn.sofifa.org/flags/45.png       85         92  Real Madrid
# ...

# %%
real_madrid.sort_values(by=['HeadingAccuracy'],ascending=False).head() # in HeadingAccuracy
# Out:
#      Unnamed: 0      ID             Name  Age  \
# 8             8  155862     Sergio Ramos   32
# 36           36  173731          G. Bale   28
# 62           62  201535        R. Varane   25
# 430         430  221639          Mariano   24
# 188         188  200724  Nacho Fernández   28
#
#                                               Photo         Nationality  \
# 8    https://cdn.sofifa.org/players/4/19/155862.png               Spain
# 36   https://cdn.sofifa.org/players/4/19/173731.png               Wales
# 62   https://cdn.sofifa.org/players/4/19/201535.png              France
# 430  https://cdn.sofifa.org/players/4/19/221639.png  Dominican Republic
# 188  https://cdn.sofifa.org/players/4/19/200724.png               Spain
#
#                                      Flag  Overall  Potential         Club  \
# 8     https://cdn.sofifa.org/flags/45.png       91         91  Real Madrid
# 36    https://cdn.sofifa.org/flags/50.png       88         88  Real Madrid
# ...

# %%
real_madrid['Nationality'].value_counts() # finding player's nationality in real madrid on basis of numbers.
# Out:
# Nationality
# Spain                 19
# France                 3
# Brazil                 3
# Germany                1
# Croatia                1
# Wales                  1
# Belgium                1
# Costa Rica             1
# Dominican Republic     1
# Uruguay                1
# Argentina              1
# Name: count, dtype: int64
